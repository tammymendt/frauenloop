# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/tamara/Projects/edgar-co2-emissions/data/edgar-co2-emissions.csv")

# %%
df.head()
# Out:
#   Code         Name                       Sector  Year  Emissions
# 0  AFG  Afghanistan                    Transport  1970   503.4713
# 1  AFG  Afghanistan  Other industrial combustion  1970   128.9440
# 2  AFG  Afghanistan                    Buildings  1970   641.5890
# 3  AFG  Afghanistan               Non-combustion  1970   457.8263
# 4  AFG  Afghanistan               Power Industry  1970    10.4453

# %%
df.query("Name=='Germany' and Sector == 'Power Industry'").plot(kind='bar', x='Year', rot=90, figsize=(15, 8))

# %%
df.query("Sector == 'Power Industry' and Year == 2016")['Emissions'].plot(kind='box')

# %%
df.query("Sector == 'Power Industry' and Year == 2016 and Emissions < 40000000")['Emissions'].plot(kind='box')

# %%
df.query("Sector == 'Power Industry' and Year == 2016").sort_values(by="Emissions", ascending=False)
# Out:
#               Code                                               Name  \
# 48578        WORLD                                              World
# 47754          CHN                                              China
# 48538          USA                     United States of America (the)
# 47998          IND                                              India
# 47873         EU28                                               EU28
# 48322          RUS                           Russian Federation (the)
# 48040          JPN                                              Japan
# 47924          DEU                                            Germany
# 48070          KOR                            Korea (the Republic of)
# 48415          ZAF                                       South Africa
# 48365          SAU                                       Saudi Arabia
# 47609          AUS                                          Australia
# ...
